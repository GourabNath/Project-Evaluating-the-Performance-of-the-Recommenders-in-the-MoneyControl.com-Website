# %% [markdown]
# ## Web Scrapping Exercises

# %% [markdown]
# ### Problem 2

# %% [markdown]
# From the following page of the moneycontrol website extract all the recommendations given by the recommenders. Arrange the scrapped data as Date, Recommenders Name, Stock Name, Target, Action, etc.
# https://www.moneycontrol.com/broker-research/markets/cash-200.html
#
# Extend the problem to extract data from multiple webpages, e.g. from 200 to 204

# %% [markdown]
# ### Libraries

# %%
#required libraries for web scrap
from urllib.request import urlopen  #to get access of webpage
from bs4 import BeautifulSoup       #to get html content

# %% [markdown]
# ### Extracting Data From a Single Page

# %% [markdown]
# If you take a look at the webpage you will find that the recommendations are small horizontal segments. if you take a look at the HTML script (using inspect element on the webpage) you will find that these are encapsulated using the div tag of HTML. Note carefully, here we are specifically interested in the 'div' tags with the class 'Ohidden'. Inside that structure there are two lines tagged with 'p'. Those are what contains the required information.

# %%
mc_html = urlopen('https://www.moneycontrol.com/broker-research/markets/cash-200.html')
mc_soup = BeautifulSoup(mc_html, 'html.parser')

# %%
div = mc_soup.find_all('div', {'class':'Ohidden'})


count = 0

for i in div:       
    try:
        print(i.find('p', {'class':'op_gl12'}).get_text())
        print(i.find('p', {'class':'MT5'}).get_text())
        print('\n')
    except:
        pass
    
    count += 1
    if count == 5:
        break
# Out:
# cash |  Dec 28, 2016 | 03:12 pm
# Buy Karnataka Bank; target of Rs 136: Arihant Capital
#
#
# cash |  Dec 26, 2016 | 04:57 pm
# Hold Maharashtra Seamless; target of Rs 240: ICICI Direct
#
#
# cash |  Dec 26, 2016 | 04:54 pm
# Buy West Coast Paper Mills; target of Rs 169: AUM Capital
#
#
# cash |  Dec 26, 2016 | 04:52 pm
# Buy Tube Investments; target of Rs 719: AUM Capital
#
#
# cash |  Dec 26, 2016 | 04:51 pm
# Buy Torrent Pharma; target of Rs 1665: Edelweiss

# %% [markdown]
# **Note:**
#
# 1. We need to extract only the date from line 1
# 2. The First word on line 2 contains the action followed by the stock name
# 3. The middle portion (between the semi-colon and the colon) contains the target
# 4. The last part of the last line contains the Recommender's name

# %%
#Let us parse these information and store them in different Lists

div = mc_soup.find_all('div', {'class':'Ohidden'})

date = []
action = []
stock = []
target = []
recommender = []

for i in div:       
    try:
        #Getting the date
        line1 = i.find('p', {'class':'op_gl12'}).get_text()
        line1 = line1.lstrip('cash | ')
        date.append(line1[: line1.find("|")-1])
        
        line2 = i.find('p', {'class':'MT5'}).get_text().strip()
        action.append(line2[:line2.find(" ")])
        stock.append(line2[line2.find(" ")+1:line2.find(";")])
        target.append(float(line2[line2.find("Rs")+3: line2.find(":", line2.find("Rs"))]))
        recommender.append(line2[line2.find(':')+1:].strip())
        
    except:
        pass

# %%
#Creating a Data Frame
import pandas as pd

dic = {'Date':date, 'Stock':stock, 'Action':action, 'Target':target, 'Recommender':recommender}
moneyControl = pd.DataFrame(dic)

# %%
moneyControl = moneyControl[['Date','Stock','Action','Target','Recommender']]
moneyControl
# Out:
#             Date                   Stock      Action  Target  \
# 0   Dec 28, 2016          Karnataka Bank         Buy   136.0
# 1   Dec 26, 2016    Maharashtra Seamless        Hold   240.0
# 2   Dec 26, 2016  West Coast Paper Mills         Buy   169.0
# 3   Dec 26, 2016        Tube Investments         Buy   719.0
# 4   Dec 26, 2016          Torrent Pharma         Buy  1665.0
# 5   Dec 26, 2016           TVS Srichakra        Hold  3175.0
# 6   Dec 21, 2016             Kaveri Seed         Buy   489.0
# 7   Dec 21, 2016         Aegis Logistics  Accumulate   167.0
# 8   Dec 21, 2016      Persistent Systems        Hold   690.0
# 9   Dec 21, 2016    Jammu & Kashmir Bank         Buy    75.0
# 10  Dec 21, 2016        Aurobindo Pharma         Buy  1050.0
# 11  Dec 19, 2016           PNC Infratech         Buy   127.0
# 12  Dec 19, 2016                    NMDC        Hold   125.0
# 13  Dec 19, 2016        Aurobindo Pharma         Buy  1050.0
# 14  Dec 19, 2016  Technocraft Industries         Buy   433.0
# 15  Dec 19, 2016            D-Link India         Buy   150.0
# 16  Dec 16, 2016        Jagran Prakashan         Buy   194.0
# 17  Dec 16, 2016        Jagran Prakashan         Buy   190.0
# 18  Dec 16, 2016        Jagran Prakashan         Buy   215.0
# 19  Dec 16, 2016             Adani Ports         Buy   330.0
#
#            Recommender
# 0      Arihant Capital
# 1         ICICI Direct
# 2          AUM Capital
# 3          AUM Capital
# 4            Edelweiss
# 5              Centrum
# 6        Motilal Oswal
# 7        CD Equisearch
# 8         ICICI Direct
# 9         ICICI Direct
# 10       Motilal Oswal
# 11  Geojit BNP Paribas
# 12        ICICI Direct
# 13       Motilal Oswal
# 14     Axis Securities
# 15        ICICI Direct
# 16           Edelweiss
# 17        ICICI Direct
# 18       Motilal Oswal
# 19         Axis Direct

# %% [markdown]
# ### Extracting Data From a Single Page (Function)

# %%
#This was from page no. 200
#Create a function to scrap the data from any page number. (input should be a page number)

#Required Libraries
import pandas as pd
from urllib.request import urlopen  #to get access of webpage
from bs4 import BeautifulSoup       #to get html content

#Functions
def moneyControlBroker(pageNo):
    mc_html = urlopen('https://www.moneycontrol.com/broker-research/markets/cash-'+str(pageNo)+'.html')
    mc_soup = BeautifulSoup(mc_html, 'html.parser')
    
    div = mc_soup.find_all('div', {'class':'Ohidden'})

    date = []
    action = []
    stock = []
    target = []
    recommender = []

    for i in div:       
        try:
            #Getting the date
            line1 = i.find('p', {'class':'op_gl12'}).get_text()
            line1 = line1.lstrip('cash | ')
            date.append(line1[: line1.find("|")-1])

            line2 = i.find('p', {'class':'MT5'}).get_text().strip()
            action.append(line2[:line2.find(" ")])
            stock.append(line2[line2.find(" ")+1:line2.find(";")])
            target.append(float(line2[line2.find("Rs")+3: line2.find(":", line2.find("Rs"))]))
            recommender.append(line2[line2.find(':')+1:].strip())

        except:
            pass

    
    dic = {'Date':date, 'Stock':stock, 'Action':action, 'Target':target, 'Recommender':recommender}
    moneyControl = pd.DataFrame(dic)
    
    moneyControl = moneyControl[['Date','Stock','Action','Target','Recommender']]
    return(moneyControl)

# %%
moneyControlBroker(201)
# Out:
#             Date                      Stock      Action  Target  \
# 0   Dec 16, 2016     Endurance Technologies         Buy   715.0
# 1   Dec 16, 2016              Bajaj Finance  Accumulate  1030.0
# 2   Dec 16, 2016              J Kumar Infra         Buy   300.0
# 3   Dec 15, 2016              PNC Infratech         Buy   128.0
# 4   Dec 15, 2016          Pennar Engineered         Buy   191.0
# 5   Dec 15, 2016                        L&T         Buy   800.0
# 6   Dec 15, 2016               DEN Networks        Hold    93.0
# 7   Dec 15, 2016                 Coal India         Buy   310.0
# 8   Dec 15, 2016                      Nalco         Buy    77.0
# 9   Dec 14, 2016                    V-Guard        Hold   191.0
# 10  Dec 14, 2016      J.Kumar Infraprojects         Buy   253.0
# 11  Dec 14, 2016       Jindal Steel & Power         Buy   100.0
# 12  Dec 14, 2016                 Sun Pharma         Buy   875.0
# 13  Dec 14, 2016        Power Mech Projects         Buy   599.0
# 14  Dec 14, 2016               Prism Cement         Buy   102.0
# 15  Dec 14, 2016        Manpasand Beverages         Buy   761.0
# 16  Dec 14, 2016                       CESC        Hold   675.0
# 17  Dec 13, 2016               Natco Pharma         Buy   725.0
# 18  Dec 13, 2016                 Tata Power         Buy    84.0
# 19  Dec 13, 2016  Prestige Estates Projects         Buy   205.0
#
#             Recommender
# 0         Motilal Oswal
# 1            KR Choksey
# 2           Axis Direct
# 3          ICICI Direct
# 4               Centrum
# 5         Motilal Oswal
# 6             Edelweiss
# 7             Edelweiss
# 8         Motilal Oswal
# 9    Geojit BNP Paribas
# 10  Prabhudas Lilladher
# 11  Prabhudas Lilladher
# 12             Religare
# 13              Centrum
# 14        Motilal Oswal
# 15        Motilal Oswal
# 16         ICICI Direct
# 17          Axis Direct
# 18              Centrum
# 19          Axis Direct

# %% [markdown]
# ### Extracting Data From Multiple Pages

# %%
#Extracting the data from page number 200 to 204

data = pd.DataFrame()
for page in range(200,205):
    df = moneyControlBroker(page)
    data = pd.concat([data, df])

# %%
data.shape

# %%
data
# Out:
#             Date                   Stock      Action   Target  \
# 0   Dec 28, 2016          Karnataka Bank         Buy    136.0
# 1   Dec 26, 2016    Maharashtra Seamless        Hold    240.0
# 2   Dec 26, 2016  West Coast Paper Mills         Buy    169.0
# 3   Dec 26, 2016        Tube Investments         Buy    719.0
# 4   Dec 26, 2016          Torrent Pharma         Buy   1665.0
# 5   Dec 26, 2016           TVS Srichakra        Hold   3175.0
# 6   Dec 21, 2016             Kaveri Seed         Buy    489.0
# 7   Dec 21, 2016         Aegis Logistics  Accumulate    167.0
# 8   Dec 21, 2016      Persistent Systems        Hold    690.0
# 9   Dec 21, 2016    Jammu & Kashmir Bank         Buy     75.0
# 10  Dec 21, 2016        Aurobindo Pharma         Buy   1050.0
# 11  Dec 19, 2016           PNC Infratech         Buy    127.0
# 12  Dec 19, 2016                    NMDC        Hold    125.0
# 13  Dec 19, 2016        Aurobindo Pharma         Buy   1050.0
# 14  Dec 19, 2016  Technocraft Industries         Buy    433.0
# 15  Dec 19, 2016            D-Link India         Buy    150.0
# 16  Dec 16, 2016        Jagran Prakashan         Buy    194.0
# 17  Dec 16, 2016        Jagran Prakashan         Buy    190.0
# 18  Dec 16, 2016        Jagran Prakashan         Buy    215.0
# 19  Dec 16, 2016             Adani Ports         Buy    330.0
# 0   Dec 16, 2016  Endurance Technologies         Buy    715.0
# 1   Dec 16, 2016           Bajaj Finance  Accumulate   1030.0
# 2   Dec 16, 2016           J Kumar Infra         Buy    300.0
# 3   Dec 15, 2016           PNC Infratech         Buy    128.0
# 4   Dec 15, 2016       Pennar Engineered         Buy    191.0
# 5   Dec 15, 2016                     L&T         Buy    800.0
# 6   Dec 15, 2016            DEN Networks        Hold     93.0
# 7   Dec 15, 2016              Coal India         Buy    310.0
# 8   Dec 15, 2016                   Nalco         Buy     77.0
# 9   Dec 14, 2016                 V-Guard        Hold    191.0
# ..           ...                     ...         ...      ...
# 10  Dec 07, 2016         Ashoka Buildcon        Hold    160.0
# 11  Dec 07, 2016      Schneider Electric         Buy    200.0
# 12  Dec 06, 2016                     MCX         Buy   1335.0
# 13  Dec 06, 2016         Ashoka Buildcon  Accumulate    174.0
# 14  Dec 06, 2016                   Cipla         Buy    700.0
# 15  Dec 06, 2016             Tata Motors         Buy    510.0
# 16  Dec 05, 2016  Shemaroo Entertainment        Sell    400.0
# 17  Dec 05, 2016         Larsen & Toubro         Buy   1589.0
# 18  Dec 05, 2016               Axis Bank        Sell    465.0
# 19  Dec 05, 2016  Gujarat State Petronet         Buy    175.0
# 0   Dec 05, 2016   Balkrishna Industries         Buy   1213.0
# 1   Dec 05, 2016              Tata Power         Buy     83.0
# 2   Dec 02, 2016         Phillips Carbon         Buy    285.0
# 3   Dec 02, 2016           Eicher Motors         Buy  25880.0
# 4   Dec 02, 2016     Sadbhav Engineering         Buy    312.0
# 5   Dec 02, 2016          Graphite India        Hold     80.0
# 6   Dec 02, 2016   Balkrishna Industries         Buy   1231.0
# 7   Dec 02, 2016     Sadbhav Engineering         Buy    416.0
# 8   Dec 02, 2016     Reliance Industries         Buy   1407.0
# 9   Dec 02, 2016   Balkrishna Industries        Hold   1216.0
# 10  Dec 02, 2016           Ashok Leyland         Buy     92.0
# 11  Dec 02, 2016   Balkrishna Industries         Buy   1400.0
# 12  Dec 02, 2016        Tube Investments         Buy    719.0
# 13  Dec 02, 2016      Talwalkars Fitness         Buy    348.0
# 14  Dec 01, 2016              Tata Power         Buy     84.0
# 15  Dec 01, 2016      Repco Home Finance         Buy    673.0
# 16  Dec 01, 2016             Cox & Kings         Buy    365.0
# 17  Dec 01, 2016            Sangam India         Buy    424.0
# 18  Dec 01, 2016  Gujarat State Petronet         Buy    174.0
# 19  Dec 01, 2016             Cox & Kings        Hold    180.0
#
#            Recommender
# 0      Arihant Capital
# 1         ICICI Direct
# 2          AUM Capital
# 3          AUM Capital
# 4            Edelweiss
# 5              Centrum
# 6        Motilal Oswal
# 7        CD Equisearch
# 8         ICICI Direct
# 9         ICICI Direct
# 10       Motilal Oswal
# 11  Geojit BNP Paribas
# 12        ICICI Direct
# 13       Motilal Oswal
# 14     Axis Securities
# 15        ICICI Direct
# 16           Edelweiss
# 17        ICICI Direct
# 18       Motilal Oswal
# 19         Axis Direct
# 0        Motilal Oswal
# 1           KR Choksey
# 2          Axis Direct
# 3         ICICI Direct
# 4              Centrum
# 5        Motilal Oswal
# 6            Edelweiss
# 7            Edelweiss
# 8        Motilal Oswal
# 9   Geojit BNP Paribas
# ..                 ...
# 10        ICICI Direct
# 11          KR Choksey
# 12     HDFC Securities
# 13                  PL
# 14        Ajcon Global
# 15  Geojit BNP Paribas
# 16            Religare
# 17  Geojit BNP Paribas
# 18            Religare
# 19         Axis Direct
# 0          Axis Direct
# 1          Axis Direct
# 2       Dynamic Levels
# 3            Edelweiss
# 4         ICICI Direct
# 5         ICICI Direct
# 6            Edelweiss
# 7            Edelweiss
# 8            Edelweiss
# 9           KR Choksey
# 10  Geojit BNP Paribas
# 11        ICICI Direct
# 12         Aum Capital
# 13          Way2Wealth
# 14             Centrum
# 15             Centrum
# 16                IIFL
# 17        Ajcon Global
# 18        ICICI Direct
# 19        ICICI Direct
#
# [100 rows x 5 columns]
